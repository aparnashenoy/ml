# %% [markdown]
# <a href="https://colab.research.google.com/github/aparnashenoy/ml/blob/master/AIS_data_geohash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
path = '/gdrive/My Drive/'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#import file
df = pd.read_csv(path + 'ais_data_version2.csv')

# %%
# !pip install pygeohash
# Out:
# ...
#   Created wheel for pygeohash: filename=pygeohash-1.2.0-py2.py3-none-any.whl size=6167 sha256=59849dc247165325361c4b45c1011daf22d08f623f61a8bcf0a5f39f75b2296a
#   Stored in directory: /root/.cache/pip/wheels/e2/ed/86/be7141d743cfb4aebac76406187154cd78fe9e6535d872187a
# Successfully built pygeohash
# ...

# %%
import pygeohash as gh

# %%
df.head()
# Out:
#    Unnamed: 0       MMSI         BaseDateTime       LAT        LON   SOG  \
# 0           0  367339240  2021-09-30T00:00:02  36.99416  -89.15366   0.3
# 1           1  316020871  2021-09-30T00:00:02  48.70558 -123.54449   0.0
# 2           2  368033750  2021-09-30T00:00:02  38.96336  -76.48107   0.0
# 3           3  338329872  2021-09-30T00:00:04  41.63435  -71.21239   0.0
# 4           4  338400879  2021-09-30T00:00:04  42.37885  -87.80212  12.7
#
#      COG  Heading        VesselName         IMO CallSign  \
# 0  350.0    328.0  SHERRYL B REEVES         NaN  WDE3451
# 1   61.4    109.0     SEASPAN EAGLE  IMO9432971  CFN6642
# 2  360.0    281.0         OCEANAIRE  IMO0000000  WDK2245
# 3  360.0    511.0           POR-SHA  IMO0000000      NaN
# 4  202.1    511.0            LADY B  IMO0000000      NaN
#
#                VesselType  Status  Length  Width  Draft  Cargo  \
# 0                 Tug Tow    12.0    48.0   12.0    NaN   57.0
# ...

# %%
df['geohash']=df.apply(lambda x: gh.encode(x.LAT, x.LON, precision=5), axis=1)

# %%
df
# Out:
#          Unnamed: 0       MMSI         BaseDateTime       LAT        LON  \
# 0                 0  367339240  2021-09-30T00:00:02  36.99416  -89.15366
# 1                 1  316020871  2021-09-30T00:00:02  48.70558 -123.54449
# 2                 2  368033750  2021-09-30T00:00:02  38.96336  -76.48107
# 3                 3  338329872  2021-09-30T00:00:04  41.63435  -71.21239
# 4                 4  338400879  2021-09-30T00:00:04  42.37885  -87.80212
# ...             ...        ...                  ...       ...        ...
# 8849475     9106173  338926439  2021-09-30T22:50:57  13.42388  144.66368
# 8849476     9106174  338926439  2021-09-30T22:59:07  13.42386  144.66368
# 8849477     9106175  338926439  2021-09-30T23:29:57  13.42385  144.66368
# 8849478     9106176  338926439  2021-09-30T23:46:26  13.42386  144.66367
# 8849479     9106177  338926439  2021-09-30T23:53:36  13.42387  144.66366
#
#           SOG    COG  Heading         VesselName         IMO CallSign  \
# ...

# %%
df.to_csv(path + 'ais_data_geohash_version3.csv')
